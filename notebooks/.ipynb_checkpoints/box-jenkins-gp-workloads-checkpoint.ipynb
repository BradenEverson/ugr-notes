# %% [markdown]
# ### ARIMA For Process Behavior Estimation using the Box-Jenkins Method
# #### Braden Everson

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
series = np.loadtxt("../gp-workloads/time_slices/cpu_intensive_1/cpu_intensive_1_waitrun_5000us.csv", delimiter=",", skiprows=1)

# %%
plt.plot(series[:, 2], series[:, 6])
